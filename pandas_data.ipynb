# %%
import pandas as pd 

df = pd.read_csv('Data/survey_results_public.csv')

df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode  ...        TimeSearching  \
# 0                                   NaN       NaN  ...                  NaN
# 1                                   NaN       NaN  ...                  NaN
# 2                                   NaN        14  ...                  NaN
# 3                                   NaN        20  ...                  NaN
# 4                                   NaN         8  ...                  NaN
# ...                                 ...       ...  ...                  ...
# 73263                             Udemy         8  ...  30-60 minutes a day
# 73264            Coursera;Udemy;Udacity         6  ...  15-30 minutes a day
# 73265  Udemy;Codecademy;Pluralsight;edX        42  ...  30-60 minutes a day
# 73266                               NaN        50  ...                  NaN
# 73267                 Udemy;Pluralsight        16  ...                  NaN
#
#                     TimeAnswering  Onboarding  \
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3                             NaN         NaN
# 4                             NaN         NaN
# ...                           ...         ...
# 73263  Less than 15 minutes a day  Just right
# 73264        60-120 minutes a day   Very long
# 73265        60-120 minutes a day  Just right
# 73266                         NaN         NaN
# 73267                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase ConvertedCompYearly
# 0                             NaN                 NaN
# 1                       Difficult                 NaN
# 2      Neither easy nor difficult             40205.0
# 3                            Easy            215232.0
# 4                            Easy                 NaN
# ...                           ...                 ...
# 73263                        Easy                 NaN
# 73264                        Easy                 NaN
# 73265                        Easy                 NaN
# 73266                        Easy                 NaN
# 73267                        Easy                 NaN
#
# [73268 rows x 79 columns]

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  PurchaseInfluence               50969 non-null  object
#  14  BuyNewTool                      67963 non-null  object
#  15  Country                         71771 non-null  object
#  16  Currency                        51264 non-null  object
#  17  CompTotal                       38422 non-null  float64
#  18  CompFreq                        44425 non-null  object
#  19  LanguageHaveWorkedWith          70975 non-null  object
#  20  LanguageWantToWorkWith          67027 non-null  object
#  21  DatabaseHaveWorkedWith          60121 non-null  object
#  22  DatabaseWantToWorkWith          51014 non-null  object
#  23  PlatformHaveWorkedWith          49924 non-null  object
#  24  PlatformWantToWorkWith          40415 non-null  object
#  25  WebframeHaveWorkedWith          53544 non-null  object
#  26  WebframeWantToWorkWith          46122 non-null  object
#  27  MiscTechHaveWorkedWith          44992 non-null  object
#  28  MiscTechWantToWorkWith          36810 non-null  object
#  29  ToolsTechHaveWorkedWith         54171 non-null  object
#  30  ToolsTechWantToWorkWith         46566 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  32  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  33  OpSysProfessional use           65503 non-null  object
#  34  OpSysPersonal use               70963 non-null  object
#  35  VersionControlSystem            71379 non-null  object
#  36  VCInteraction                   68156 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  42  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  43  Blockchain                      71071 non-null  object
#  44  NEWSOSites                      71365 non-null  object
#  45  SOVisitFreq                     70961 non-null  object
#  46  SOAccount                       71572 non-null  object
#  47  SOPartFreq                      58229 non-null  object
#  48  SOComm                          71408 non-null  object
#  49  Age                             70946 non-null  object
#  50  Gender                          70853 non-null  object
#  51  Trans                           70315 non-null  object
#  52  Sexuality                       66565 non-null  object
#  53  Ethnicity                       69474 non-null  object
#  54  Accessibility                   67244 non-null  object
#  55  MentalHealth                    66447 non-null  object
#  56  TBranch                         52670 non-null  object
#  57  ICorPM                          36283 non-null  object
#  58  WorkExp                         36769 non-null  float64
#  59  Knowledge_1                     35804 non-null  object
#  60  Knowledge_2                     34973 non-null  object
#  61  Knowledge_3                     35133 non-null  object
#  62  Knowledge_4                     35097 non-null  object
#  63  Knowledge_5                     35014 non-null  object
#  64  Knowledge_6                     34991 non-null  object
#  65  Knowledge_7                     34977 non-null  object
#  66  Frequency_1                     35371 non-null  object
#  67  Frequency_2                     35344 non-null  object
#  68  Frequency_3                     34515 non-null  object
#  69  TimeSearching                   36198 non-null  object
#  70  TimeAnswering                   36022 non-null  object
#  71  Onboarding                      35679 non-null  object
#  72  ProfessionalTech                34906 non-null  object
#  73  TrueFalse_1                     35819 non-null  object
#  74  TrueFalse_2                     35715 non-null  object
#  75  TrueFalse_3                     35749 non-null  object
#  76  SurveyLength                    70444 non-null  object
#  77  SurveyEase                      70508 non-null  object
#  78  ConvertedCompYearly             38071 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 44.2+ MB

# %%
pd.set_option('display.max_columns',79)
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 0                                       NaN
# 1                              Fully remote
# 2      Hybrid (some remote, some in-person)
# 3                              Fully remote
# 4      Hybrid (some remote, some in-person)
# ...                                     ...
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 0                                                    NaN
# 1               Hobby;Contribute to open-source projects
# 2                                                  Hobby
# 3                           I don’t code outside of work
# 4                                                  Hobby
# ...                                                  ...
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 0                                                  NaN
# 1                                                  NaN
# 2      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# 3      Books / Physical media;School (i.e., Universit...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Technical documentation;Blogs;Programming Game...
# 3                                                    NaN
# 4      Technical documentation;Blogs;Stack Overflow;O...
# ...                                                  ...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 0                                   NaN       NaN          NaN
# 1                                   NaN       NaN          NaN
# 2                                   NaN        14            5
# 3                                   NaN        20           17
# 4                                   NaN         8            3
# ...                                 ...       ...          ...
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Data scientist or machine learning specialist;...
# 3                                  Developer, full-stack
# 4      Developer, front-end;Developer, full-stack;Dev...
# ...                                                  ...
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 0                       NaN                               NaN
# 1                       NaN                               NaN
# 2        20 to 99 employees             I have some influence
# 3      100 to 499 employees             I have some influence
# 4        20 to 99 employees             I have some influence
# ...                     ...                               ...
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                Other (please specify):
# 4      Start a free trial;Visit developer communities...
# ...                                                  ...
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 0                                                    NaN
# 1                                                 Canada
# 2      United Kingdom of Great Britain and Northern I...
# 3                                                 Israel
# 4                               United States of America
# ...                                                  ...
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 0                            NaN        NaN      NaN
# 1           CAD\tCanadian dollar        NaN      NaN
# 2            GBP\tPound sterling    32000.0   Yearly
# 3        ILS\tIsraeli new shekel    60000.0  Monthly
# 4      USD\tUnited States dollar        NaN      NaN
# ...                          ...        ...      ...
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1                                  JavaScript;TypeScript
# 2                      C#;C++;HTML/CSS;JavaScript;Python
# 3                           C#;JavaScript;SQL;TypeScript
# 4            C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...                                                  ...
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 0                                                 NaN
# 1                                     Rust;TypeScript
# 2               C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                                   C#;SQL;TypeScript
# 4          C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
# ...                                               ...
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Microsoft SQL Se...
# ...                                                  ...
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   Microsoft SQL Server
# 3                                   Microsoft SQL Server
# 4      Cloud Firestore;Elasticsearch;Firebase Realtim...
# ...                                                  ...
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                    Firebase;Microsoft Azure
# ...                                       ...
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                               Firebase;Microsoft Azure
# ...                                                  ...
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                        Angular.js
# 3                             ASP.NET;ASP.NET Core
# 4      Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
# ...                                             ...
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                     Angular;Angular.js
# 3                                  ASP.NET;ASP.NET Core
# 4                   Angular;ASP.NET Core ;Blazor;Node.js
# ...                                                  ...
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                 Pandas
# 3                                                   .NET
# 4                                                   .NET
# ...                                                  ...
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                   .NET
# 3                                                   .NET
# 4                                      .NET;Apache Kafka
# ...                                                  ...
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         npm
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                           Docker;Kubernetes
# ...                                       ...
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Notepad++;Visual Studio
# 3             Notepad++;Visual Studio;Visual Studio Code
# 4       Notepad++;Visual Studio;Visual Studio Code;Xcode
# ...                                                  ...
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                 macOS
# 2                             Notepad++;Visual Studio               Windows
# 3          Notepad++;Visual Studio;Visual Studio Code               Windows
# 4              Rider;Visual Studio;Visual Studio Code               Windows
# ...                                               ...                   ...
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#                        OpSysPersonal use         VersionControlSystem  \
# 0                                    NaN                          NaN
# 1      Windows Subsystem for Linux (WSL)                          Git
# 2                                Windows                          Git
# 3                                Windows                          Git
# 4                          macOS;Windows  Git;Other (please specify):
# ...                                  ...                          ...
# 73263                  Linux-based;macOS                          Git
# 73264                Linux-based;Windows                          Git
# 73265                            Windows                          Git
# 73266                            Windows                          SVN
# 73267                Linux-based;Windows                          Git
#
#                                            VCInteraction  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            Code editor
# 3      Code editor;Command-line;Version control hosti...
# 4                                            Code editor
# ...                                                  ...
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# ...                      ...                        ...
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                       Jira Work Management;Trello
# 4                                               NaN
# ...                                             ...
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN               Microsoft Teams
# 3        Jira Work Management;Trello                    Slack;Zoom
# 4                                NaN          Microsoft Teams;Zoom
# ...                              ...                           ...
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                               NaN               NaN
# 1                               NaN  Very unfavorable
# 2                   Microsoft Teams  Very unfavorable
# 3                        Slack;Zoom  Very unfavorable
# 4                               NaN       Unfavorable
# ...                             ...               ...
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 0                                                    NaN
# 1      Collectives on Stack Overflow;Stack Overflow f...
# 2      Collectives on Stack Overflow;Stack Overflow;S...
# 3      Collectives on Stack Overflow;Stack Overflow f...
# 4      Collectives on Stack Overflow;Stack Overflow f...
# ...                                                  ...
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 0                         NaN                      NaN
# 1       Daily or almost daily                      Yes
# 2      Multiple times per day                      Yes
# 3       Daily or almost daily                      Yes
# 4      Multiple times per day                      Yes
# ...                       ...                      ...
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 0                                                    NaN              NaN
# 1                                  Daily or almost daily         Not sure
# 2                                 Multiple times per day          Neutral
# 3                                   A few times per week  Yes, definitely
# 4                                  Daily or almost daily  Yes, definitely
# ...                                                  ...              ...
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 0                  NaN    NaN   NaN                      NaN
# 1                  NaN    NaN   NaN                      NaN
# 2      25-34 years old    Man    No                 Bisexual
# 3      35-44 years old    Man    No  Straight / Heterosexual
# 4      25-34 years old    NaN   NaN                      NaN
# ...                ...    ...   ...                      ...
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                       White  None of the above
# 3                       White  None of the above
# 4                         NaN                NaN
# ...                       ...                ...
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 0                                                    NaN     NaN
# 1                                                    NaN      No
# 2      I have a mood or emotional disorder (e.g., dep...      No
# 3                                      None of the above      No
# 4                                                    NaN      No
# ...                                                  ...     ...
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 0                          NaN      NaN         NaN
# 1                          NaN      NaN         NaN
# 2                          NaN      NaN         NaN
# 3                          NaN      NaN         NaN
# 4                          NaN      NaN         NaN
# ...                        ...      ...         ...
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 0                             NaN                         NaN             NaN
# 1                             NaN                         NaN             NaN
# 2                             NaN                         NaN             NaN
# 3                             NaN                         NaN             NaN
# 4                             NaN                         NaN             NaN
# ...                           ...                         ...             ...
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 0                 NaN             NaN                         NaN
# 1                 NaN             NaN                         NaN
# 2                 NaN             NaN                         NaN
# 3                 NaN             NaN                         NaN
# 4                 NaN             NaN                         NaN
# ...               ...             ...                         ...
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
# ...                 ...                ...               ...
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 0                      NaN                         NaN         NaN
# 1                      NaN                         NaN         NaN
# 2                      NaN                         NaN         NaN
# 3                      NaN                         NaN         NaN
# 4                      NaN                         NaN         NaN
# ...                    ...                         ...         ...
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0             NaN         NaN                    NaN
# 1             NaN         NaN               Too long
# 2             NaN         NaN  Appropriate in length
# 3             NaN         NaN  Appropriate in length
# 4             NaN         NaN               Too long
# ...           ...         ...                    ...
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 0                             NaN                  NaN
# 1                       Difficult                  NaN
# 2      Neither easy nor difficult              40205.0
# 3                            Easy             215232.0
# 4                            Easy                  NaN
# ...                           ...                  ...
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
#
# [73268 rows x 79 columns]

# %%
df_schema = pd.read_csv('Data/survey_results_schema.csv')
df_schema
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR
# ..        ...   ...      ...
# 74        NaN    MC     MAVR
# 75        NaN    MC     MAVR
# 76        NaN    MC     MAVR
# 77        NaN    MC     MAVR
# 78        NaN    MC     MAVR
#
# [79 rows x 6 columns]

# %%
pd.set_option('display.max_rows',79)
df_schema
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# 27  QID265              MiscTech
# 28  QID275             ToolsTech
# 29  QID274        NEWCollabTools
# 30   QID71                 OpSys
# 31  QID283  VersionControlSystem
# 32  QID284         VCInteraction
# 33  QID285             VCHosting
# 34  QID282      OfficeStackAsync
# 35  QID307       OfficeStackSync
# 36  QID305            Blockchain
# 37   QID91                    S4
# 38  QID266            NEWSOSites
# 39  QID100           SOVisitFreq
# 40  QID101             SOAccount
# 41  QID102            SOPartFreq
# 42  QID106                SOComm
# 43  QID121                    S5
# 44  QID127                   Age
# 45  QID122                Gender
# 46  QID153                 Trans
# 47  QID136             Sexuality
# 48  QID126             Ethnicity
# 49  QID124         Accessibility
# 50  QID125          MentalHealth
# 51  QID295                    S6
# 52  QID299               TBranch
# 53  QID287                ICorPM
# 54  QID288               WorkExp
# 55  QID289             Knowledge
# 56  QID290             Frequency
# 57  QID291         TimeSearching
# 58  QID292         TimeAnswering
# 59  QID293            Onboarding
# 60  QID304      ProfessionalTech
# 61  QID286          SOTeamsUsage
# 62  QID294             TrueFalse
# 63  QID131                    S7
# 64  QID132          SurveyLength
# 65  QID133            SurveyEase
# 66  QID289           Knowledge_1
# 67  QID289           Knowledge_2
# 68  QID289           Knowledge_3
# 69  QID289           Knowledge_4
# 70  QID289           Knowledge_5
# 71  QID289           Knowledge_6
# 72  QID289           Knowledge_7
# 73  QID290           Frequency_1
# 74  QID290           Frequency_2
# 75  QID290           Frequency_3
# 76  QID294           TrueFalse_1
# 77  QID294           TrueFalse_2
# 78  QID294           TrueFalse_3
#
#                                              question force_resp    type  \
# 0   <div><span style="font-size:19px;"><strong>Hel...      False      DB
# 1                                   Browser Meta Info      False    Meta
# 2   <span style="font-size:22px; font-family: aria...      False      DB
# 3   Which of the following options best describes ...       True      MC
# 4   Which of the following best describes your cur...      False      MC
# 5   Which best describes your current work situation?      False      MC
# 6   Which of the following best describes the code...      False      MC
# 7   <span style="font-size:22px; font-family: aria...      False      DB
# 8   Which of the following best describes the high...      False      MC
# 9   How did you learn to code? Select all that apply.      False      MC
# 10  What online resources do you use to learn to c...      False      MC
# 11  What online courses or certifications do you u...      False      MC
# 12  Including any education, how many years have y...      False      MC
# 13  NOT including education, how many years have y...      False      MC
# 14  Which of the following describes your current ...      False      MC
# 15  Approximately how many people are employed by ...      False      MC
# 16  What level of influence do you, personally, ha...      False      MC
# 17  When buying a new tool or software, how do you...      False      MC
# 18  Where do you live? <span style="font-weight: b...       True      MC
# 19  Which currency do you use day-to-day? If your ...       True      MC
# 20  What is your current total compensation (salar...      False      TE
# 21   Is that compensation weekly, monthly, or yearly?      False      MC
# 22  <span style="font-size:22px; font-family: aria...      False      DB
# 23  Which <b>programming, scripting, and markup la...      False  Matrix
# 24  Which <b>database environments </b>have you do...      False  Matrix
# 25  Which <b>cloud platforms</b> have you done ext...      False  Matrix
# 26  Which <b>web frameworks and web technologies</...      False  Matrix
# 27  Which <b>other frameworks and libraries</b> ha...      False  Matrix
# 28  Which <b>developer </b><strong>tools</strong> ...      False  Matrix
# 29  Which <strong>development environments</strong...      False  Matrix
# 30  What is the primary <b>operating system</b> in...      False  Matrix
# 31  What are the primary <b>version control system...      False      MC
# 32  How do you interact with your version control ...      False      MC
# 33  What version control hosting service are you u...      False  Matrix
# 34  Which <b>collaborative work management tools</...      False  Matrix
# 35  Which <b>communication tools</b> did you use r...      False  Matrix
# 36  How favorable are you about blockchain, crypto...      False      MC
# 37  <span style="font-size:22px; font-family: aria...      False      DB
# 38  Which of the following Stack Overflow sites ha...      False      MC
# 39  How frequently would you say you visit Stack O...      False      MC
# 40              Do you have a Stack Overflow account?      False      MC
# 41  How frequently would you say you participate i...      False      MC
# 42  Do you consider yourself a member of the Stack...      False      MC
# 43  <span style="font-size:22px; font-family: aria...      False      DB
# 44                                  What is your age?      False      MC
# 45  Which of the following describe you, if any? P...      False      MC
# 46                    Do you identify as transgender?      False      MC
# 47  Which of the following describe you, if any? P...      False      MC
# 48  Which of the following describe you, if any? P...      False      MC
# 49  Which of the following describe you, if any? P...      False      MC
# 50  Which of the following describe you, if any? P...      False      MC
# 51  <span style="font-size:22px; font-family: aria...      False      DB
# 52  <span style="font-size:16px;">Would you like t...       True      MC
# 53  Are you an independent contributor or people m...      False      MC
# 54  How many years of working experience do you have?      False  Slider
# 55  Please rate your level of agreement with the f...      False  Matrix
# 56  How frequently do you experience each of the f...      False  Matrix
# 57  On an average day, how much time do you typica...      False      MC
# 58  On an average day, how much time do you typica...      False      MC
# 59  The time it takes to onboard new hires at my c...      False      MC
# 60                                    My company has:      False      MC
# 61       Does your team use Stack Overflow for Teams?      False      MC
# 62                              Last few questions...      False  Matrix
# 63  <span style="font-size:22px;"><strong>Final Qu...      False      DB
# 64  How do you feel about the length of the survey...      False      MC
# 65  How easy or difficult was this survey to compl...      False      MC
# 66  I have interactions with people outside of my ...        NaN      MC
# 67  Knowledge silos prevent me from getting ideas ...        NaN      MC
# 68  I can find up-to-date information within my or...        NaN      MC
# 69  I am able to quickly find answers to my questi...        NaN      MC
# 70  I know which system or resource to use to find...        NaN      MC
# 71  I often find myself answering questions that I...        NaN      MC
# 72  Waiting on answers to questions often causes i...        NaN      MC
# 73  Needing help from people outside of your immed...        NaN      MC
# 74  Interacting with people outside of your immedi...        NaN      MC
# 75  Encountering knowledge silos (where one indivi...        NaN      MC
# 76  Are you involved in supporting new hires durin...        NaN      MC
# 77  Do you use learning resources provided by your...        NaN      MC
# 78  Does your employer give you time to learn new ...        NaN      MC
#
#    selector
# 0        TB
# 1   Browser
# 2        TB
# 3      SAVR
# 4      MAVR
# 5      SAVR
# 6      MAVR
# 7        TB
# 8      SAVR
# 9      MAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16     SAVR
# 17     MAVR
# 18       DL
# 19       DL
# 20       SL
# 21     MAVR
# 22       TB
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27   Likert
# 28   Likert
# 29   Likert
# 30   Likert
# 31     MAVR
# 32     MAVR
# 33   Likert
# 34   Likert
# 35   Likert
# 36     SAVR
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43       TB
# 44     MAVR
# 45     MAVR
# 46     MAVR
# 47     MAVR
# 48     MAVR
# 49     MAVR
# 50     MAVR
# 51       TB
# 52     SAVR
# 53     SAVR
# 54  HSLIDER
# 55   Likert
# 56   Likert
# 57     SAVR
# 58     SAVR
# 59     SAVR
# 60     MAVR
# 61     SAVR
# 62   Likert
# 63       TB
# 64     MAVR
# 65     MAVR
# 66     MAVR
# 67     MAVR
# 68     MAVR
# 69     MAVR
# 70     MAVR
# 71     MAVR
# 72     MAVR
# 73     MAVR
# 74     MAVR
# 75     MAVR
# 76     MAVR
# 77     MAVR
# 78     MAVR

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode YearsCodePro                                            DevType  \
# 0       NaN          NaN                                                NaN
# 1       NaN          NaN                                                NaN
# 2        14            5  Data scientist or machine learning specialist;...
# 3        20           17                              Developer, full-stack
# 4         8            3  Developer, front-end;Developer, full-stack;Dev...
#
#                 OrgSize      PurchaseInfluence  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2    20 to 99 employees  I have some influence
# 3  100 to 499 employees  I have some influence
# 4    20 to 99 employees  I have some influence
#
#                                           BuyNewTool  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                            Other (please specify):
# 4  Start a free trial;Visit developer communities...
#
#                                              Country  \
# 0                                                NaN
# 1                                             Canada
# 2  United Kingdom of Great Britain and Northern I...
# 3                                             Israel
# 4                           United States of America
#
#                     Currency  CompTotal CompFreq  \
# 0                        NaN        NaN      NaN
# 1       CAD\tCanadian dollar        NaN      NaN
# 2        GBP\tPound sterling    32000.0   Yearly
# 3    ILS\tIsraeli new shekel    60000.0  Monthly
# 4  USD\tUnited States dollar        NaN      NaN
#
#                         LanguageHaveWorkedWith  \
# 0                                          NaN
# 1                        JavaScript;TypeScript
# 2            C#;C++;HTML/CSS;JavaScript;Python
# 3                 C#;JavaScript;SQL;TypeScript
# 4  C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#
#                        LanguageWantToWorkWith  \
# 0                                         NaN
# 1                             Rust;TypeScript
# 2       C#;C++;HTML/CSS;JavaScript;TypeScript
# 3                           C#;SQL;TypeScript
# 4  C#;Elixir;F#;Go;JavaScript;Rust;TypeScript
#
#                               DatabaseHaveWorkedWith  \
# 0                                                NaN
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Microsoft SQL Se...
#
#                               DatabaseWantToWorkWith  \
# 0                                                NaN
# 1                                                NaN
# 2                               Microsoft SQL Server
# 3                               Microsoft SQL Server
# 4  Cloud Firestore;Elasticsearch;Firebase Realtim...
#
#      PlatformHaveWorkedWith    PlatformWantToWorkWith  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4  Firebase;Microsoft Azure  Firebase;Microsoft Azure
#
#                          WebframeHaveWorkedWith  \
# 0                                           NaN
# 1                                           NaN
# 2                                    Angular.js
# 3                         ASP.NET;ASP.NET Core
# 4  Angular;ASP.NET;ASP.NET Core ;jQuery;Node.js
#
#                  WebframeWantToWorkWith MiscTechHaveWorkedWith  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                    Angular;Angular.js                 Pandas
# 3                 ASP.NET;ASP.NET Core                    .NET
# 4  Angular;ASP.NET Core ;Blazor;Node.js                   .NET
#
#   MiscTechWantToWorkWith ToolsTechHaveWorkedWith ToolsTechWantToWorkWith  \
# 0                    NaN                     NaN                     NaN
# 1                    NaN                     NaN                     NaN
# 2                   .NET                     NaN                     NaN
# 3                   .NET                     NaN                     NaN
# 4      .NET;Apache Kafka                     npm       Docker;Kubernetes
#
#                        NEWCollabToolsHaveWorkedWith  \
# 0                                               NaN
# 1                                               NaN
# 2                           Notepad++;Visual Studio
# 3        Notepad++;Visual Studio;Visual Studio Code
# 4  Notepad++;Visual Studio;Visual Studio Code;Xcode
#
#                  NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 0                                         NaN                   NaN
# 1                                         NaN                 macOS
# 2                     Notepad++;Visual Studio               Windows
# 3  Notepad++;Visual Studio;Visual Studio Code               Windows
# 4      Rider;Visual Studio;Visual Studio Code               Windows
#
#                    OpSysPersonal use         VersionControlSystem  \
# 0                                NaN                          NaN
# 1  Windows Subsystem for Linux (WSL)                          Git
# 2                            Windows                          Git
# 3                            Windows                          Git
# 4                      macOS;Windows  Git;Other (please specify):
#
#                                        VCInteraction  VCHostingPersonal use  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                        Code editor                    NaN
# 3  Code editor;Command-line;Version control hosti...                    NaN
# 4                                        Code editor                    NaN
#
#    VCHostingProfessional use OfficeStackAsyncHaveWorkedWith  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN    Jira Work Management;Trello
# 4                        NaN                            NaN
#
#   OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN               Microsoft Teams
# 3    Jira Work Management;Trello                    Slack;Zoom
# 4                            NaN          Microsoft Teams;Zoom
#
#   OfficeStackSyncWantToWorkWith        Blockchain  \
# 0                           NaN               NaN
# 1                           NaN  Very unfavorable
# 2               Microsoft Teams  Very unfavorable
# 3                    Slack;Zoom  Very unfavorable
# 4                           NaN       Unfavorable
#
#                                           NEWSOSites             SOVisitFreq  \
# 0                                                NaN                     NaN
# 1  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 2  Collectives on Stack Overflow;Stack Overflow;S...  Multiple times per day
# 3  Collectives on Stack Overflow;Stack Overflow f...   Daily or almost daily
# 4  Collectives on Stack Overflow;Stack Overflow f...  Multiple times per day
#
#   SOAccount              SOPartFreq           SOComm              Age Gender  \
# 0       NaN                     NaN              NaN              NaN    NaN
# 1       Yes   Daily or almost daily         Not sure              NaN    NaN
# 2       Yes  Multiple times per day          Neutral  25-34 years old    Man
# 3       Yes    A few times per week  Yes, definitely  35-44 years old    Man
# 4       Yes   Daily or almost daily  Yes, definitely  25-34 years old    NaN
#
#   Trans                Sexuality Ethnicity      Accessibility  \
# 0   NaN                      NaN       NaN                NaN
# 1   NaN                      NaN       NaN                NaN
# 2    No                 Bisexual     White  None of the above
# 3    No  Straight / Heterosexual     White  None of the above
# 4   NaN                      NaN       NaN                NaN
#
#                                         MentalHealth TBranch ICorPM  WorkExp  \
# 0                                                NaN     NaN    NaN      NaN
# 1                                                NaN      No    NaN      NaN
# 2  I have a mood or emotional disorder (e.g., dep...      No    NaN      NaN
# 3                                  None of the above      No    NaN      NaN
# 4                                                NaN      No    NaN      NaN
#
#   Knowledge_1 Knowledge_2 Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Knowledge_7 Frequency_1 Frequency_2 Frequency_3 TimeSearching TimeAnswering  \
# 0         NaN         NaN         NaN         NaN           NaN           NaN
# 1         NaN         NaN         NaN         NaN           NaN           NaN
# 2         NaN         NaN         NaN         NaN           NaN           NaN
# 3         NaN         NaN         NaN         NaN           NaN           NaN
# 4         NaN         NaN         NaN         NaN           NaN           NaN
#
#   Onboarding ProfessionalTech TrueFalse_1 TrueFalse_2 TrueFalse_3  \
# 0        NaN              NaN         NaN         NaN         NaN
# 1        NaN              NaN         NaN         NaN         NaN
# 2        NaN              NaN         NaN         NaN         NaN
# 3        NaN              NaN         NaN         NaN         NaN
# 4        NaN              NaN         NaN         NaN         NaN
#
#             SurveyLength                  SurveyEase  ConvertedCompYearly
# 0                    NaN                         NaN                  NaN
# 1               Too long                   Difficult                  NaN
# 2  Appropriate in length  Neither easy nor difficult              40205.0
# 3  Appropriate in length                        Easy             215232.0
# 4               Too long                        Easy                  NaN

# %%
df_schema.head()
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
df.tail()
# Out:
#        ResponseId                                         MainBranch  \
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                EdLevel  \
# 73263     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                     OrgSize                 PurchaseInfluence  \
# 73263  100 to 499 employees             I have some influence
# 73264          I don’t know     I have little or no influence
# 73265    20 to 99 employees  I have a great deal of influence
# 73266    10 to 19 employees  I have a great deal of influence
# 73267                   NaN                               NaN
#
#                                               BuyNewTool  \
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                LanguageWantToWorkWith  \
# 73263  Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                      HTML/CSS;JavaScript;Python
# 73265           C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                          Delphi
# 73267                      PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                       ToolsTechWantToWorkWith  \
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                       npm;Unreal Engine
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith OpSysProfessional use  \
# 73263             Sublime Text;Vim;Visual Studio Code                 macOS
# 73264         Notepad++;Spyder;Vim;Visual Studio Code   Linux-based;Windows
# 73265         Spyder;Visual Studio;Visual Studio Code               Windows
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio               Windows
# 73267                       Neovim;Visual Studio Code   Linux-based;Windows
#
#          OpSysPersonal use VersionControlSystem  \
# 73263    Linux-based;macOS                  Git
# 73264  Linux-based;Windows                  Git
# 73265              Windows                  Git
# 73266              Windows                  SVN
# 73267  Linux-based;Windows                  Git
#
#                                            VCInteraction  \
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility       MentalHealth TBranch  \
# 73263                 African  None of the above  None of the above     Yes
# 73264                   White  None of the above  None of the above     Yes
# 73265             Multiracial  None of the above  None of the above     Yes
# 73266                European  None of the above  None of the above      No
# 73267  Or, in your own words:  None of the above  None of the above     NaN
#
#                         ICorPM  WorkExp Knowledge_1  \
# 73263  Independent contributor      5.0       Agree
# 73264  Independent contributor      6.0       Agree
# 73265  Independent contributor     42.0    Disagree
# 73266                      NaN      NaN         NaN
# 73267                      NaN      NaN         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#           Knowledge_5     Knowledge_6                 Knowledge_7  \
# 73263  Strongly agree  Strongly agree  Neither agree nor disagree
# 73264        Disagree           Agree                       Agree
# 73265           Agree           Agree  Neither agree nor disagree
# 73266             NaN             NaN                         NaN
# 73267             NaN             NaN                         NaN
#
#             Frequency_1        Frequency_2       Frequency_3  \
# 73263             Never              Never             Never
# 73264  1-2 times a week  6-10 times a week  10+ times a week
# 73265             Never              Never             Never
# 73266               NaN                NaN               NaN
# 73267               NaN                NaN               NaN
#
#              TimeSearching               TimeAnswering  Onboarding  \
# 73263  30-60 minutes a day  Less than 15 minutes a day  Just right
# 73264  15-30 minutes a day        60-120 minutes a day   Very long
# 73265  30-60 minutes a day        60-120 minutes a day  Just right
# 73266                  NaN                         NaN         NaN
# 73267                  NaN                         NaN         NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength SurveyEase  \
# 73263         Yes         Yes               Too long       Easy
# 73264         Yes         Yes               Too long       Easy
# 73265          No          No  Appropriate in length       Easy
# 73266         NaN         NaN  Appropriate in length       Easy
# 73267         NaN         NaN  Appropriate in length       Easy
#
#        ConvertedCompYearly
# 73263                  NaN
# 73264                  NaN
# 73265                  NaN
# 73266                  NaN
# 73267                  NaN

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# 73260             Employed, full-time;Student, part-time
# 73261                                Employed, full-time
# 73262             Student, full-time;Employed, part-time
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73258  Hybrid (some remote, some in-person)
# 73259  Hybrid (some remote, some in-person)
# 73260  Hybrid (some remote, some in-person)
# 73261  Hybrid (some remote, some in-person)
# 73262  Hybrid (some remote, some in-person)
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 73258                                              Hobby
# 73259                            Other (please specify):
# 73260                            School or academic work
# 73261                                              Hobby
# 73262                            School or academic work
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel  \
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73259    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73260       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73261    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73262  Secondary school (e.g. American high school, G...
# 73263       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 73258  Other online resources (e.g., videos, blogs, f...
# 73259  Books / Physical media;Other online resources ...
# 73260            School (i.e., University, College, etc)
# 73261  Books / Physical media;Other online resources ...
# 73262  Other online resources (e.g., videos, blogs, f...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 73258  Stack Overflow;Video-based Online Courses;Onli...
# 73259  Technical documentation;Blogs;Written Tutorial...
# 73260                                                NaN
# 73261  Technical documentation;Blogs;Programming Game...
# 73262  Technical documentation;Written Tutorials;Stac...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 73258                    Coursera;Udemy         5            1
# 73259                               NaN         6            2
# 73260                               NaN         8          NaN
# 73261      Udemy;Codecademy;Pluralsight         9            2
# 73262                               NaN         4          NaN
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 73258                                Developer, back-end
# 73259                                Developer, back-end
# 73260                        Developer, back-end;Student
# 73261                              Developer, full-stack
# 73262                       Developer, front-end;Student
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                         OrgSize                 PurchaseInfluence  \
# 73258      100 to 499 employees             I have some influence
# 73259        10 to 19 employees     I have little or no influence
# 73260                       NaN                               NaN
# 73261  10,000 or more employees     I have little or no influence
# 73262                       NaN                               NaN
# 73263      100 to 499 employees             I have some influence
# 73264              I don’t know     I have little or no influence
# 73265        20 to 99 employees  I have a great deal of influence
# 73266        10 to 19 employees  I have a great deal of influence
# 73267                       NaN                               NaN
#
#                                               BuyNewTool  \
# 73258  Start a free trial;Ask developers I know/work ...
# 73259  Start a free trial;Ask developers I know/work ...
# 73260  Visit developer communities like Stack Overflo...
# 73261  Start a free trial;Visit developer communities...
# 73262                                                NaN
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 73258                                              India
# 73259                                             Poland
# 73260                                            Belgium
# 73261                                             France
# 73262                                            Germany
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 73258          INR\tIndian rupee  3200000.0   Yearly
# 73259          PLN\tPolish zloty     8000.0  Monthly
# 73260                        NaN        NaN      NaN
# 73261          EUR European Euro    36000.0   Yearly
# 73262                        NaN        NaN      NaN
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 73258                                        Go;Java;SQL
# 73259                                             Elixir
# 73260                                                 C#
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73262                     Assembly;C;C++;Java;TypeScript
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                   LanguageWantToWorkWith  \
# 73258                              JavaScript;TypeScript
# 73259                                             Elixir
# 73260                                                 C#
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Pyt...
# 73262                                           C++;Java
# 73263     Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                         HTML/CSS;JavaScript;Python
# 73265              C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                             Delphi
# 73267                         PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 73258                                      MongoDB;MySQL
# 73259                                         PostgreSQL
# 73260                               Microsoft SQL Server
# 73261                                              MySQL
# 73262                                                NaN
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 73258                                        MySQL;Redis
# 73259                                         PostgreSQL
# 73260                               Microsoft SQL Server
# 73261                  Elasticsearch;MongoDB;MySQL;Redis
# 73262                                                NaN
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                        PlatformHaveWorkedWith  \
# 73258                                     AWS
# 73259                              AWS;Heroku
# 73260                         Microsoft Azure
# 73261                         Microsoft Azure
# 73262                                     NaN
# 73263           AWS;DigitalOcean;Google Cloud
# 73264                                     NaN
# 73265  Managed Hosting;Microsoft Azure;VMware
# 73266                                     NaN
# 73267                         Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 73258                                       Google Cloud
# 73259                                                AWS
# 73260                                    Microsoft Azure
# 73261                                    Microsoft Azure
# 73262                                                NaN
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                              WebframeHaveWorkedWith  \
# 73258                                           NaN
# 73259                                jQuery;Phoenix
# 73260                         ASP.NET;ASP.NET Core
# 73261             Angular;Angular.js;Drupal;Node.js
# 73262                                       Node.js
# 73263                       Express;FastAPI;Node.js
# 73264                        FastAPI;Flask;React.js
# 73265                              ASP.NET;React.js
# 73266                                           NaN
# 73267  ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 73258                                                NaN
# 73259                                            Phoenix
# 73260                               ASP.NET Core ;Blazor
# 73261                                    Angular;Node.js
# 73262                                                NaN
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 73258                                Apache Kafka;Spring
# 73259                                       React Native
# 73260                                               .NET
# 73261                                             Spring
# 73262                                                NaN
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 73258                                                NaN
# 73259                                                NaN
# 73260                                               .NET
# 73261                                             Spring
# 73262                                                NaN
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 73258          Docker;Homebrew;Kubernetes;npm
# 73259                       Docker;Kubernetes
# 73260                                  Docker
# 73261                              Docker;npm
# 73262                                     npm
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                                  ToolsTechWantToWorkWith  \
# 73258                                         Kubernetes
# 73259                                  Docker;Kubernetes
# 73260                                  Docker;Kubernetes
# 73261  Ansible;Chef;Docker;Kubernetes;npm;Terraform;Yarn
# 73262                                                NaN
# 73263                     Docker;Homebrew;Kubernetes;npm
# 73264                                                NaN
# 73265                                  npm;Unreal Engine
# 73266                                                NaN
# 73267             Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 73258              Eclipse;GoLand;Vim;Visual Studio Code
# 73259                                 Visual Studio Code
# 73260                   Visual Studio;Visual Studio Code
# 73261               Eclipse;Notepad++;Visual Studio Code
# 73262                         Eclipse;Visual Studio Code
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                          NEWCollabToolsWantToWorkWith  \
# 73258                   GoLand;Vim;Visual Studio Code
# 73259                              Visual Studio Code
# 73260                Visual Studio;Visual Studio Code
# 73261                     IntelliJ;Visual Studio Code
# 73262               Android Studio;Visual Studio Code
# 73263             Sublime Text;Vim;Visual Studio Code
# 73264         Notepad++;Spyder;Vim;Visual Studio Code
# 73265         Spyder;Visual Studio;Visual Studio Code
# 73266  RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                       Neovim;Visual Studio Code
#
#                                    OpSysProfessional use  \
# 73258                                              macOS
# 73259                                              macOS
# 73260                                            Windows
# 73261  Linux-based;Windows;Windows Subsystem for Linu...
# 73262                                                NaN
# 73263                                              macOS
# 73264                                Linux-based;Windows
# 73265                                            Windows
# 73266                                            Windows
# 73267                                Linux-based;Windows
#
#                                OpSysPersonal use VersionControlSystem  \
# 73258                        Linux-based;Windows                  Git
# 73259  Windows;Windows Subsystem for Linux (WSL)                  Git
# 73260                                    Windows                  Git
# 73261  Windows;Windows Subsystem for Linux (WSL)                  Git
# 73262                        Linux-based;Windows                  Git
# 73263                          Linux-based;macOS                  Git
# 73264                        Linux-based;Windows                  Git
# 73265                                    Windows                  Git
# 73266                                    Windows                  SVN
# 73267                        Linux-based;Windows                  Git
#
#                                            VCInteraction  \
# 73258                                       Command-line
# 73259                           Code editor;Command-line
# 73260  Code editor;Command-line;Version control hosti...
# 73261  Code editor;Command-line;Version control hosti...
# 73262                                       Command-line
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 73258                    NaN                        NaN
# 73259                    NaN                        NaN
# 73260                    NaN                        NaN
# 73261                    NaN                        NaN
# 73262                    NaN                        NaN
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 73258                                        Notion
# 73259                  ClickUp;Jira Work Management
# 73260                                        Notion
# 73261                          Jira Work Management
# 73262                                        Notion
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#       OfficeStackAsyncWantToWorkWith OfficeStackSyncHaveWorkedWith  \
# 73258                            NaN                    Slack;Zoom
# 73259           Jira Work Management         Microsoft Teams;Slack
# 73260                        ClickUp          Microsoft Teams;Zoom
# 73261                            NaN               Microsoft Teams
# 73262                         Notion                    Slack;Zoom
# 73263           Jira Work Management                    Slack;Zoom
# 73264                            NaN                    Rocketchat
# 73265                Microsoft Lists          Microsoft Teams;Zoom
# 73266                            NaN                          Zoom
# 73267                            NaN    Microsoft Teams;Slack;Zoom
#
#       OfficeStackSyncWantToWorkWith        Blockchain  \
# 73258                           NaN    Very favorable
# 73259                         Slack            Unsure
# 73260               Microsoft Teams       Unfavorable
# 73261               Microsoft Teams       Unfavorable
# 73262                           NaN            Unsure
# 73263                    Slack;Zoom    Very favorable
# 73264                           NaN            Unsure
# 73265          Microsoft Teams;Zoom  Very unfavorable
# 73266                          Zoom       Indifferent
# 73267                    Slack;Zoom         Favorable
#
#                                               NEWSOSites  \
# 73258                      Stack Overflow;Stack Exchange
# 73259                                     Stack Overflow
# 73260                                     Stack Overflow
# 73261                                     Stack Overflow
# 73262                                     Stack Overflow
# 73263                      Stack Overflow;Stack Exchange
# 73264                                     Stack Overflow
# 73265                      Stack Overflow;Stack Exchange
# 73266                                     Stack Overflow
# 73267  Collectives on Stack Overflow;Stack Overflow;S...
#
#                   SOVisitFreq                SOAccount  \
# 73258   Daily or almost daily                      Yes
# 73259    A few times per week                      Yes
# 73260   Daily or almost daily                      Yes
# 73261   Daily or almost daily                      Yes
# 73262    A few times per week                      Yes
# 73263   Daily or almost daily                      Yes
# 73264   Daily or almost daily  Not sure/can't remember
# 73265  Multiple times per day                      Yes
# 73266   Daily or almost daily                      Yes
# 73267   Daily or almost daily                      Yes
#
#                                               SOPartFreq           SOComm  \
# 73258                Less than once per month or monthly    Yes, somewhat
# 73259  I have never participated in Q&A on Stack Over...   No, not at all
# 73260                Less than once per month or monthly    Yes, somewhat
# 73261  I have never participated in Q&A on Stack Over...   No, not really
# 73262                Less than once per month or monthly   No, not really
# 73263                    A few times per month or weekly  Yes, definitely
# 73264                                                NaN          Neutral
# 73265                Less than once per month or monthly    Yes, somewhat
# 73266  I have never participated in Q&A on Stack Over...   No, not at all
# 73267                Less than once per month or monthly    Yes, somewhat
#
#                    Age Gender Trans                Sexuality  \
# 73258  18-24 years old    Man    No  Straight / Heterosexual
# 73259  25-34 years old    Man    No  Straight / Heterosexual
# 73260  18-24 years old    Man    No  Straight / Heterosexual
# 73261  18-24 years old    Man    No                      NaN
# 73262  18-24 years old    Man    No  Straight / Heterosexual
# 73263  25-34 years old    Man    No  Straight / Heterosexual
# 73264  25-34 years old    Man    No  Straight / Heterosexual
# 73265  55-64 years old    Man    No  Straight / Heterosexual
# 73266  55-64 years old    Man    No  Straight / Heterosexual
# 73267  25-34 years old    Man    No  Straight / Heterosexual
#
#                     Ethnicity      Accessibility  \
# 73258                   Asian                NaN
# 73259          White;European  None of the above
# 73260                European  None of the above
# 73261                European  None of the above
# 73262                European  None of the above
# 73263                 African  None of the above
# 73264                   White  None of the above
# 73265             Multiracial  None of the above
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 73258                                  None of the above     Yes
# 73259                                  None of the above     Yes
# 73260  I have a concentration and/or memory disorder ...     Yes
# 73261                                  None of the above     Yes
# 73262  I have a mood or emotional disorder (e.g., dep...     NaN
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp                 Knowledge_1  \
# 73258  Independent contributor      1.0              Strongly agree
# 73259  Independent contributor      2.0                       Agree
# 73260  Independent contributor      3.0  Neither agree nor disagree
# 73261  Independent contributor      2.0                       Agree
# 73262                      NaN      NaN                         NaN
# 73263  Independent contributor      5.0                       Agree
# 73264  Independent contributor      6.0                       Agree
# 73265  Independent contributor     42.0                    Disagree
# 73266                      NaN      NaN                         NaN
# 73267                      NaN      NaN                         NaN
#
#                       Knowledge_2                 Knowledge_3     Knowledge_4  \
# 73258                    Disagree              Strongly agree           Agree
# 73259                    Disagree                       Agree  Strongly agree
# 73260                       Agree                       Agree           Agree
# 73261                       Agree                       Agree           Agree
# 73262                         NaN                         NaN             NaN
# 73263                    Disagree              Strongly agree  Strongly agree
# 73264                       Agree  Neither agree nor disagree        Disagree
# 73265  Neither agree nor disagree                    Disagree           Agree
# 73266                         NaN                         NaN             NaN
# 73267                         NaN                         NaN             NaN
#
#                       Knowledge_5                 Knowledge_6  \
# 73258  Neither agree nor disagree                       Agree
# 73259              Strongly agree  Neither agree nor disagree
# 73260  Neither agree nor disagree                       Agree
# 73261                       Agree  Neither agree nor disagree
# 73262                         NaN                         NaN
# 73263              Strongly agree              Strongly agree
# 73264                    Disagree                       Agree
# 73265                       Agree                       Agree
# 73266                         NaN                         NaN
# 73267                         NaN                         NaN
#
#                       Knowledge_7       Frequency_1        Frequency_2  \
# 73258                       Agree  1-2 times a week   10+ times a week
# 73259              Strongly agree             Never   1-2 times a week
# 73260              Strongly agree             Never   1-2 times a week
# 73261                    Disagree  1-2 times a week   3-5 times a week
# 73262                         NaN               NaN                NaN
# 73263  Neither agree nor disagree             Never              Never
# 73264                       Agree  1-2 times a week  6-10 times a week
# 73265  Neither agree nor disagree             Never              Never
# 73266                         NaN               NaN                NaN
# 73267                         NaN               NaN                NaN
#
#             Frequency_3        TimeSearching               TimeAnswering  \
# 73258             Never  15-30 minutes a day         15-30 minutes a day
# 73259               NaN  15-30 minutes a day  Less than 15 minutes a day
# 73260  1-2 times a week  15-30 minutes a day         30-60 minutes a day
# 73261  1-2 times a week  15-30 minutes a day         15-30 minutes a day
# 73262               NaN                  NaN                         NaN
# 73263             Never  30-60 minutes a day  Less than 15 minutes a day
# 73264  10+ times a week  15-30 minutes a day        60-120 minutes a day
# 73265             Never  30-60 minutes a day        60-120 minutes a day
# 73266               NaN                  NaN                         NaN
# 73267               NaN                  NaN                         NaN
#
#            Onboarding                                   ProfessionalTech  \
# 73258      Just right  DevOps function;Microservices;Developer portal...
# 73259  Somewhat short  DevOps function;Continuous integration (CI) an...
# 73260       Very long  DevOps function;Developer portal or other cent...
# 73261   Somewhat long  Innersource initiative;DevOps function;Microse...
# 73262             NaN                                                NaN
# 73263      Just right  DevOps function;Microservices;Developer portal...
# 73264       Very long                                      None of these
# 73265      Just right                                      None of these
# 73266             NaN                                                NaN
# 73267             NaN                                                NaN
#
#       TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 73258         Yes         Yes         Yes               Too long
# 73259         Yes         Yes         Yes  Appropriate in length
# 73260          No          No         Yes  Appropriate in length
# 73261         Yes         Yes         Yes  Appropriate in length
# 73262         NaN         NaN         NaN  Appropriate in length
# 73263         Yes         Yes         Yes               Too long
# 73264          No         Yes         Yes               Too long
# 73265          No          No          No  Appropriate in length
# 73266         NaN         NaN         NaN  Appropriate in length
# 73267         NaN         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 73258  Neither easy nor difficult                  NaN
# 73259  Neither easy nor difficult                  NaN
# 73260                        Easy                  NaN
# 73261                        Easy                  NaN
# 73262  Neither easy nor difficult                  NaN
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN

# %%
df_schema.tail()
# Out:
#        qid        qname                                           question  \
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp type selector
# 74        NaN   MC     MAVR
# 75        NaN   MC     MAVR
# 76        NaN   MC     MAVR
# 77        NaN   MC     MAVR
# 78        NaN   MC     MAVR

# %%
df_schema.tail(12)
# Out:
#        qid        qname                                           question  \
# 67  QID289  Knowledge_2  Knowledge silos prevent me from getting ideas ...
# 68  QID289  Knowledge_3  I can find up-to-date information within my or...
# 69  QID289  Knowledge_4  I am able to quickly find answers to my questi...
# 70  QID289  Knowledge_5  I know which system or resource to use to find...
# 71  QID289  Knowledge_6  I often find myself answering questions that I...
# 72  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 73  QID290  Frequency_1  Needing help from people outside of your immed...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp type selector
# 67        NaN   MC     MAVR
# 68        NaN   MC     MAVR
# 69        NaN   MC     MAVR
# 70        NaN   MC     MAVR
# 71        NaN   MC     MAVR
# 72        NaN   MC     MAVR
# 73        NaN   MC     MAVR
# 74        NaN   MC     MAVR
# 75        NaN   MC     MAVR
# 76        NaN   MC     MAVR
# 77        NaN   MC     MAVR
# 78        NaN   MC     MAVR

# %%
df.tail(23)
# Out:
#        ResponseId                                         MainBranch  \
# 73245       73246                        I code primarily as a hobby
# 73246       73247                     I am a developer by profession
# 73247       73248                        I code primarily as a hobby
# 73248       73249                     I am a developer by profession
# 73249       73250                              I am learning to code
# 73250       73251                     I am a developer by profession
# 73251       73252                     I am a developer by profession
# 73252       73253                              I am learning to code
# 73253       73254                     I am a developer by profession
# 73254       73255  I am not primarily a developer, but I write co...
# 73255       73256                     I am a developer by profession
# 73256       73257                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73245             Student, full-time;Employed, part-time
# 73246                                Employed, full-time
# 73247                                I prefer not to say
# 73248  Independent contractor, freelancer, or self-em...
# 73249                                 Student, full-time
# 73250  Employed, full-time;Independent contractor, fr...
# 73251                                Employed, full-time
# 73252                                 Student, part-time
# 73253                                Employed, full-time
# 73254                                Employed, full-time
# 73255                                Employed, full-time
# 73256             Student, part-time;Employed, part-time
# 73257                                 Student, full-time
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# 73260             Employed, full-time;Student, part-time
# 73261                                Employed, full-time
# 73262             Student, full-time;Employed, part-time
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73245                        Full in-person
# 73246                          Fully remote
# 73247                                   NaN
# 73248                          Fully remote
# 73249                                   NaN
# 73250                          Fully remote
# 73251  Hybrid (some remote, some in-person)
# 73252                                   NaN
# 73253  Hybrid (some remote, some in-person)
# 73254  Hybrid (some remote, some in-person)
# 73255  Hybrid (some remote, some in-person)
# 73256  Hybrid (some remote, some in-person)
# 73257                                   NaN
# 73258  Hybrid (some remote, some in-person)
# 73259  Hybrid (some remote, some in-person)
# 73260  Hybrid (some remote, some in-person)
# 73261  Hybrid (some remote, some in-person)
# 73262  Hybrid (some remote, some in-person)
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# 73266  Hybrid (some remote, some in-person)
# 73267                          Fully remote
#
#                                         CodingActivities  \
# 73245                      Hobby;School or academic work
# 73246                                              Hobby
# 73247                                                NaN
# 73248           Hobby;Contribute to open-source projects
# 73249                                                NaN
# 73250                            Freelance/contract work
# 73251                                              Hobby
# 73252                                                NaN
# 73253                      Hobby;School or academic work
# 73254                                              Hobby
# 73255                      Hobby;Freelance/contract work
# 73256                            School or academic work
# 73257                                                NaN
# 73258                                              Hobby
# 73259                            Other (please specify):
# 73260                            School or academic work
# 73261                                              Hobby
# 73262                            School or academic work
# 73263                            Freelance/contract work
# 73264                                              Hobby
# 73265                      Hobby;School or academic work
# 73266                                              Hobby
# 73267  Hobby;Contribute to open-source projects;Boots...
#
#                                                  EdLevel  \
# 73245                                     Something else
# 73246  Some college/university study without earning ...
# 73247                                     Something else
# 73248       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73249       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73250    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73251    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73252       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73253    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73254    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73255       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73256       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73257  Secondary school (e.g. American high school, G...
# 73258       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73259    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73260       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73261    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73262  Secondary school (e.g. American high school, G...
# 73263       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73264    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 73265       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73266       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 73267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 73245  Other online resources (e.g., videos, blogs, f...
# 73246  Books / Physical media;Other online resources ...
# 73247  Other online resources (e.g., videos, blogs, f...
# 73248  Books / Physical media;School (i.e., Universit...
# 73249  Friend or family member;Other online resources...
# 73250  Books / Physical media;Other online resources ...
# 73251  Other online resources (e.g., videos, blogs, f...
# 73252  Other online resources (e.g., videos, blogs, f...
# 73253  Friend or family member;Other online resources...
# 73254  Books / Physical media;Friend or family member...
# 73255  Other online resources (e.g., videos, blogs, f...
# 73256  Books / Physical media;Other online resources ...
# 73257  Books / Physical media;Other online resources ...
# 73258  Other online resources (e.g., videos, blogs, f...
# 73259  Books / Physical media;Other online resources ...
# 73260            School (i.e., University, College, etc)
# 73261  Books / Physical media;Other online resources ...
# 73262  Other online resources (e.g., videos, blogs, f...
# 73263  Books / Physical media;Other online resources ...
# 73264  Other online resources (e.g., videos, blogs, f...
# 73265  Books / Physical media;Other online resources ...
# 73266         Books / Physical media;On the job training
# 73267  Books / Physical media;Friend or family member...
#
#                                          LearnCodeOnline  \
# 73245  Technical documentation;Blogs;Written Tutorial...
# 73246  Technical documentation;Blogs;Stack Overflow;O...
# 73247  Technical documentation;Blogs;Written Tutorial...
# 73248                                                NaN
# 73249  Technical documentation;Stack Overflow;Video-b...
# 73250  Technical documentation;Blogs;Stack Overflow;H...
# 73251  Technical documentation;Blogs;Written Tutorial...
# 73252  Technical documentation;Blogs;Stack Overflow;C...
# 73253  Programming Games;Stack Overflow;Video-based O...
# 73254  Technical documentation;Blogs;Written Tutorial...
# 73255  Technical documentation;Blogs;Stack Overflow;O...
# 73256  Technical documentation;Stack Overflow;Online ...
# 73257  Technical documentation;Blogs;Written Tutorial...
# 73258  Stack Overflow;Video-based Online Courses;Onli...
# 73259  Technical documentation;Blogs;Written Tutorial...
# 73260                                                NaN
# 73261  Technical documentation;Blogs;Programming Game...
# 73262  Technical documentation;Written Tutorials;Stac...
# 73263  Technical documentation;Blogs;Written Tutorial...
# 73264  Technical documentation;Blogs;Written Tutorial...
# 73265  Technical documentation;Programming Games;Stac...
# 73266                                                NaN
# 73267  Technical documentation;Blogs;Programming Game...
#
#                    LearnCodeCoursesCert YearsCode YearsCodePro  \
# 73245                               NaN         6          NaN
# 73246         Coursera;Udemy;Codecademy        10            5
# 73247                             Other         4          NaN
# 73248                  Udemy;Codecademy        44           35
# 73249                     Udemy;Udacity         1          NaN
# 73250                    Coursera;Udemy        12            9
# 73251                      Coursera;edX        12            8
# 73252                               NaN         3          NaN
# 73253                             Udemy         5            3
# 73254     Coursera;Udemy;Codecademy;edX         7            6
# 73255                               NaN        14            7
# 73256                    Coursera;Udemy         9          NaN
# 73257                               NaN         7          NaN
# 73258                    Coursera;Udemy         5            1
# 73259                               NaN         6            2
# 73260                               NaN         8          NaN
# 73261      Udemy;Codecademy;Pluralsight         9            2
# 73262                               NaN         4          NaN
# 73263                             Udemy         8            5
# 73264            Coursera;Udemy;Udacity         6            5
# 73265  Udemy;Codecademy;Pluralsight;edX        42           33
# 73266                               NaN        50           31
# 73267                 Udemy;Pluralsight        16            5
#
#                                                  DevType  \
# 73245                                            Student
# 73246  Developer, back-end;Developer, desktop or ente...
# 73247                                                NaN
# 73248                                Developer, back-end
# 73249                                                NaN
# 73250              Developer, back-end;DevOps specialist
# 73251                              Developer, full-stack
# 73252                                                NaN
# 73253                                Developer, back-end
# 73254  Data scientist or machine learning specialist;...
# 73255                              Developer, full-stack
# 73256                                     Engineer, data
# 73257                                                NaN
# 73258                                Developer, back-end
# 73259                                Developer, back-end
# 73260                        Developer, back-end;Student
# 73261                              Developer, full-stack
# 73262                       Developer, front-end;Student
# 73263                                Developer, back-end
# 73264      Data scientist or machine learning specialist
# 73265  Developer, full-stack;Developer, desktop or en...
# 73266  Developer, front-end;Developer, desktop or ent...
# 73267  Developer, front-end;Engineer, data;Engineer, ...
#
#                                                  OrgSize  \
# 73245                                                NaN
# 73246                           10,000 or more employees
# 73247                                                NaN
# 73248  Just me - I am a freelancer, sole proprietor, ...
# 73249                                                NaN
# 73250                           1,000 to 4,999 employees
# 73251                                 20 to 99 employees
# 73252                                                NaN
# 73253                               500 to 999 employees
# 73254                           10,000 or more employees
# 73255                               100 to 499 employees
# 73256                                                NaN
# 73257                                                NaN
# 73258                               100 to 499 employees
# 73259                                 10 to 19 employees
# 73260                                                NaN
# 73261                           10,000 or more employees
# 73262                                                NaN
# 73263                               100 to 499 employees
# 73264                                       I don’t know
# 73265                                 20 to 99 employees
# 73266                                 10 to 19 employees
# 73267                                                NaN
#
#                       PurchaseInfluence  \
# 73245                               NaN
# 73246             I have some influence
# 73247                               NaN
# 73248  I have a great deal of influence
# 73249                               NaN
# 73250             I have some influence
# 73251             I have some influence
# 73252                               NaN
# 73253     I have little or no influence
# 73254             I have some influence
# 73255     I have little or no influence
# 73256                               NaN
# 73257                               NaN
# 73258             I have some influence
# 73259     I have little or no influence
# 73260                               NaN
# 73261     I have little or no influence
# 73262                               NaN
# 73263             I have some influence
# 73264     I have little or no influence
# 73265  I have a great deal of influence
# 73266  I have a great deal of influence
# 73267                               NaN
#
#                                               BuyNewTool  \
# 73245                                                NaN
# 73246  Start a free trial;Ask developers I know/work ...
# 73247  Start a free trial;Visit developer communities...
# 73248  Start a free trial;Visit developer communities...
# 73249                                 Start a free trial
# 73250  Start a free trial;Ask developers I know/work ...
# 73251  Start a free trial;Ask developers I know/work ...
# 73252                                 Start a free trial
# 73253                    Ask developers I know/work with
# 73254  Start a free trial;Ask developers I know/work ...
# 73255                                                NaN
# 73256  Visit developer communities like Stack Overflo...
# 73257  Visit developer communities like Stack Overflo...
# 73258  Start a free trial;Ask developers I know/work ...
# 73259  Start a free trial;Ask developers I know/work ...
# 73260  Visit developer communities like Stack Overflo...
# 73261  Start a free trial;Visit developer communities...
# 73262                                                NaN
# 73263  Visit developer communities like Stack Overflo...
# 73264  Other (please specify):;Ask developers I know/...
# 73265  Start a free trial;Ask developers I know/work ...
# 73266  Start a free trial;Visit developer communities...
# 73267  Start a free trial;Visit developer communities...
#
#                                                  Country  \
# 73245  United Kingdom of Great Britain and Northern I...
# 73246                                 Russian Federation
# 73247                                            Germany
# 73248  United Kingdom of Great Britain and Northern I...
# 73249                                             Brazil
# 73250                                            Croatia
# 73251                                             France
# 73252                                        Philippines
# 73253                                          Australia
# 73254                           United States of America
# 73255                                              India
# 73256                                            Romania
# 73257                                              India
# 73258                                              India
# 73259                                             Poland
# 73260                                            Belgium
# 73261                                             France
# 73262                                            Germany
# 73263                                            Nigeria
# 73264                           United States of America
# 73265                           United States of America
# 73266  United Kingdom of Great Britain and Northern I...
# 73267                                             Canada
#
#                         Currency  CompTotal CompFreq  \
# 73245                        NaN        NaN      NaN
# 73246         RUB\tRussian ruble   150000.0  Monthly
# 73247                        NaN        NaN      NaN
# 73248        GBP\tPound sterling    11000.0  Monthly
# 73249                        NaN        NaN      NaN
# 73250         HRK\tCroatian kuna        NaN  Monthly
# 73251          EUR European Euro    65000.0   Yearly
# 73252                        NaN        NaN      NaN
# 73253     AUD\tAustralian dollar   121000.0   Yearly
# 73254  USD\tUnited States dollar   115000.0   Yearly
# 73255          INR\tIndian rupee        NaN  Monthly
# 73256                        NaN        NaN      NaN
# 73257                        NaN        NaN      NaN
# 73258          INR\tIndian rupee  3200000.0   Yearly
# 73259          PLN\tPolish zloty     8000.0  Monthly
# 73260                        NaN        NaN      NaN
# 73261          EUR European Euro    36000.0   Yearly
# 73262                        NaN        NaN      NaN
# 73263  USD\tUnited States dollar    60000.0   Yearly
# 73264  USD\tUnited States dollar   107000.0   Yearly
# 73265  USD\tUnited States dollar        NaN      NaN
# 73266        GBP\tPound sterling    58500.0   Yearly
# 73267                        NaN        NaN      NaN
#
#                                   LanguageHaveWorkedWith  \
# 73245           C++;Haskell;HTML/CSS;Java;JavaScript;SQL
# 73246                                Java;JavaScript;SQL
# 73247  Go;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 73248                        Clojure;Java;JavaScript;SQL
# 73249                    Delphi;HTML/CSS;Java;Python;SQL
# 73250           C#;HTML/CSS;JavaScript;Python;TypeScript
# 73251  Java;JavaScript;Python;Ruby;Scala;Swift;TypeSc...
# 73252                                       C;JavaScript
# 73253                                                 Go
# 73254                                                  R
# 73255  Bash/Shell;C#;HTML/CSS;JavaScript;Perl;PowerSh...
# 73256               C++;Java;JavaScript;Python;Scala;SQL
# 73257                                       C;Python;SQL
# 73258                                        Go;Java;SQL
# 73259                                             Elixir
# 73260                                                 C#
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73262                     Assembly;C;C++;Java;TypeScript
# 73263  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                      C#;Delphi;VBA
# 73267        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
#                                   LanguageWantToWorkWith  \
# 73245                                       Clojure;Dart
# 73246                         Java;JavaScript;Kotlin;SQL
# 73247      Go;HTML/CSS;JavaScript;Python;Rust;TypeScript
# 73248                                        Clojure;SQL
# 73249                                    Delphi;Java;SQL
# 73250                                      C#;TypeScript
# 73251       Haskell;Kotlin;Python;Scala;Swift;TypeScript
# 73252                                  JavaScript;Python
# 73253                                     Go;Python;Rust
# 73254                                           Python;R
# 73255  Bash/Shell;C#;HTML/CSS;JavaScript;Perl;PowerSh...
# 73256                                       Go;Scala;SQL
# 73257                                              C;C++
# 73258                              JavaScript;TypeScript
# 73259                                             Elixir
# 73260                                                 C#
# 73261  Bash/Shell;HTML/CSS;Java;JavaScript;Kotlin;Pyt...
# 73262                                           C++;Java
# 73263     Bash/Shell;Go;JavaScript;Python;SQL;TypeScript
# 73264                         HTML/CSS;JavaScript;Python
# 73265              C#;HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                             Delphi
# 73267                         PowerShell;Rust;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 73245                                         PostgreSQL
# 73246                                             Oracle
# 73247                                    MariaDB;MongoDB
# 73248                          DynamoDB;PostgreSQL;Redis
# 73249                            MySQL;Oracle;PostgreSQL
# 73250  Elasticsearch;Microsoft SQL Server;PostgreSQL;...
# 73251  Cassandra;Cloud Firestore;Elasticsearch;MongoD...
# 73252                                      MongoDB;MySQL
# 73253                                         PostgreSQL
# 73254                                                NaN
# 73255                       Microsoft SQL Server;MongoDB
# 73256                                   MySQL;PostgreSQL
# 73257                                              MySQL
# 73258                                      MongoDB;MySQL
# 73259                                         PostgreSQL
# 73260                               Microsoft SQL Server
# 73261                                              MySQL
# 73262                                                NaN
# 73263               Elasticsearch;MySQL;PostgreSQL;Redis
# 73264                Elasticsearch;MongoDB;Oracle;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                Microsoft SQL Server;MongoDB;Oracle
# 73267                   Microsoft SQL Server;Neo4j;Redis
#
#                                   DatabaseWantToWorkWith  \
# 73245                                             SQLite
# 73246                                             Oracle
# 73247                                            MongoDB
# 73248                                         PostgreSQL
# 73249                            MySQL;Oracle;PostgreSQL
# 73250                     Elasticsearch;PostgreSQL;Redis
# 73251  Cassandra;Cloud Firestore;Elasticsearch;Postgr...
# 73252                                            MongoDB
# 73253                  DynamoDB;MongoDB;PostgreSQL;Redis
# 73254                                                NaN
# 73255                       Microsoft SQL Server;MongoDB
# 73256  Cassandra;Elasticsearch;MariaDB;MongoDB;MySQL;...
# 73257                                                NaN
# 73258                                        MySQL;Redis
# 73259                                         PostgreSQL
# 73260                               Microsoft SQL Server
# 73261                  Elasticsearch;MongoDB;MySQL;Redis
# 73262                                                NaN
# 73263                             MySQL;PostgreSQL;Redis
# 73264                         Elasticsearch;Neo4j;SQLite
# 73265  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 73266                                                NaN
# 73267                                        Neo4j;Redis
#
#                                   PlatformHaveWorkedWith  \
# 73245                                                NaN
# 73246                                             Heroku
# 73247  Colocation;DigitalOcean;Heroku;Linode;Oracle C...
# 73248                                   AWS;Google Cloud
# 73249                                                NaN
# 73250          AWS;Firebase;Google Cloud;Microsoft Azure
# 73251                                       Firebase;OVH
# 73252                                             Heroku
# 73253                                       Google Cloud
# 73254                                                AWS
# 73255                                                NaN
# 73256                             Microsoft Azure;VMware
# 73257                                                NaN
# 73258                                                AWS
# 73259                                         AWS;Heroku
# 73260                                    Microsoft Azure
# 73261                                    Microsoft Azure
# 73262                                                NaN
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265             Managed Hosting;Microsoft Azure;VMware
# 73266                                                NaN
# 73267                                    Microsoft Azure
#
#                                   PlatformWantToWorkWith  \
# 73245                                                NaN
# 73246                                                AWS
# 73247  Colocation;Linode;Oracle Cloud Infrastructure;OVH
# 73248                                                AWS
# 73249                                                NaN
# 73250                                           Firebase
# 73251                          AWS;Firebase;Google Cloud
# 73252                                         AWS;Heroku
# 73253                                   AWS;Google Cloud
# 73254                                                NaN
# 73255                                                NaN
# 73256                   AWS;Google Cloud;Microsoft Azure
# 73257                                                NaN
# 73258                                       Google Cloud
# 73259                                                AWS
# 73260                                    Microsoft Azure
# 73261                                    Microsoft Azure
# 73262                                                NaN
# 73263                      AWS;DigitalOcean;Google Cloud
# 73264                                                NaN
# 73265  Firebase;Linode;Managed Hosting;Microsoft Azur...
# 73266                                                NaN
# 73267         AWS;Google Cloud;Microsoft Azure;OpenStack
#
#                                   WebframeHaveWorkedWith  \
# 73245                   Express;Next.js;Node.js;React.js
# 73246                                   Node.js;React.js
# 73247               Express;FastAPI;Flask;jQuery;Node.js
# 73248                                                NaN
# 73249                                    Next.js;Node.js
# 73250  Angular;ASP.NET;ASP.NET Core ;Express;Node.js;...
# 73251  Angular.js;Express;jQuery;Next.js;Node.js;Play...
# 73252                           Express;Node.js;React.js
# 73253                                                NaN
# 73254                                                NaN
# 73255                              Angular;ASP.NET Core
# 73256                                     ASP.NET;jQuery
# 73257                                                NaN
# 73258                                                NaN
# 73259                                     jQuery;Phoenix
# 73260                              ASP.NET;ASP.NET Core
# 73261                  Angular;Angular.js;Drupal;Node.js
# 73262                                            Node.js
# 73263                            Express;FastAPI;Node.js
# 73264                             FastAPI;Flask;React.js
# 73265                                   ASP.NET;React.js
# 73266                                                NaN
# 73267       ASP.NET Core ;Blazor;Node.js;React.js;Svelte
#
#                                   WebframeWantToWorkWith  \
# 73245                                                NaN
# 73246                                   Node.js;React.js
# 73247                            Express;FastAPI;Node.js
# 73248                                                NaN
# 73249                                                NaN
# 73250                      ASP.NET Core ;Express;Node.js
# 73251                           Express;Next.js;React.js
# 73252              Django;Express;Flask;Node.js;React.js
# 73253                                                NaN
# 73254                                                NaN
# 73255                     Angular;ASP.NET Core ;React.js
# 73256                                             jQuery
# 73257                                                NaN
# 73258                                                NaN
# 73259                                            Phoenix
# 73260                               ASP.NET Core ;Blazor
# 73261                                    Angular;Node.js
# 73262                                                NaN
# 73263                            Express;FastAPI;Node.js
# 73264                                   FastAPI;React.js
# 73265  ASP.NET;ASP.NET Core ;Blazor;Laravel;Next.js;R...
# 73266                                                NaN
# 73267                       ASP.NET Core ;Node.js;Svelte
#
#                                   MiscTechHaveWorkedWith  \
# 73245                                                 Qt
# 73246                                             Spring
# 73247                                           Electron
# 73248                                       Apache Kafka
# 73249                                                NaN
# 73250                                               .NET
# 73251                                Apache Kafka;Spring
# 73252                                                NaN
# 73253                                                NaN
# 73254                                          Tidyverse
# 73255                                               .NET
# 73256                   Apache Spark;Hadoop;NumPy;Pandas
# 73257                                               .NET
# 73258                                Apache Kafka;Spring
# 73259                                       React Native
# 73260                                               .NET
# 73261                                             Spring
# 73262                                                NaN
# 73263                                            Flutter
# 73264  Keras;NumPy;Pandas;Scikit-learn;TensorFlow;Tor...
# 73265                           .NET;Pandas;React Native
# 73266                                                NaN
# 73267                          Apache Kafka;Apache Spark
#
#                                   MiscTechWantToWorkWith  \
# 73245                                      Qt;TensorFlow
# 73246                                             Spring
# 73247                                 Flutter;TensorFlow
# 73248                                                NaN
# 73249                                                NaN
# 73250                                               .NET
# 73251       Apache Kafka;Apache Spark;Flutter;TensorFlow
# 73252                                                NaN
# 73253                                                NaN
# 73254  Keras;NumPy;Pandas;Scikit-learn;Tidyverse;Tens...
# 73255                                               .NET
# 73256  Apache Kafka;Apache Spark;Hadoop;NumPy;Pandas;...
# 73257                                                NaN
# 73258                                                NaN
# 73259                                                NaN
# 73260                                               .NET
# 73261                                             Spring
# 73262                                                NaN
# 73263                                                NaN
# 73264  NumPy;Pandas;Torch/PyTorch;Hugging Face Transf...
# 73265     .NET;Cordova;Ionic;Pandas;React Native;Xamarin
# 73266                                                NaN
# 73267                                                NaN
#
#                       ToolsTechHaveWorkedWith  \
# 73245                            npm;Unity 3D
# 73246                         Docker;npm;Yarn
# 73247                              Docker;npm
# 73248             Docker;Kubernetes;Terraform
# 73249                                     NaN
# 73250                   Docker;Kubernetes;npm
# 73251                Chef;Docker;Homebrew;npm
# 73252                                     npm
# 73253    Docker;Homebrew;Kubernetes;Terraform
# 73254                                     NaN
# 73255                   Docker;Kubernetes;npm
# 73256                             Docker;Yarn
# 73257                                     NaN
# 73258          Docker;Homebrew;Kubernetes;npm
# 73259                       Docker;Kubernetes
# 73260                                  Docker
# 73261                              Docker;npm
# 73262                                     npm
# 73263          Docker;Homebrew;Kubernetes;npm
# 73264                                     NaN
# 73265                                     npm
# 73266                                     NaN
# 73267  Docker;Kubernetes;npm;Pulumi;Terraform
#
#                                  ToolsTechWantToWorkWith  \
# 73245                                                NaN
# 73246             Docker;npm;Unity 3D;Unreal Engine;Yarn
# 73247                              Docker;Kubernetes;npm
# 73248                                             Docker
# 73249                                                NaN
# 73250                              Docker;Kubernetes;npm
# 73251           Docker;Homebrew;Kubernetes;npm;Terraform
# 73252                                           npm;Yarn
# 73253               Docker;Homebrew;Kubernetes;Terraform
# 73254                                                NaN
# 73255                              Docker;Kubernetes;npm
# 73256                             Docker;Kubernetes;Yarn
# 73257                                                NaN
# 73258                                         Kubernetes
# 73259                                  Docker;Kubernetes
# 73260                                  Docker;Kubernetes
# 73261  Ansible;Chef;Docker;Kubernetes;npm;Terraform;Yarn
# 73262                                                NaN
# 73263                     Docker;Homebrew;Kubernetes;npm
# 73264                                                NaN
# 73265                                  npm;Unreal Engine
# 73266                                                NaN
# 73267             Docker;Kubernetes;npm;Pulumi;Terraform
#
#                             NEWCollabToolsHaveWorkedWith  \
# 73245    Qt Creator;Vim;Visual Studio;Visual Studio Code
# 73246          Android Studio;IntelliJ;Notepad++;PyCharm
# 73247  Android Studio;Atom;Eclipse;GoLand;IntelliJ;Na...
# 73248                                              Emacs
# 73249               IntelliJ;NetBeans;Visual Studio Code
# 73250               Vim;Visual Studio;Visual Studio Code
# 73251                  IntelliJ;Visual Studio Code;Xcode
# 73252                                 Visual Studio Code
# 73253                                             GoLand
# 73254                                            RStudio
# 73255         Notepad++;Visual Studio;Visual Studio Code
# 73256  CLion;IntelliJ;Notepad++;Rider;Vim;Visual Stud...
# 73257                   Visual Studio;Visual Studio Code
# 73258              Eclipse;GoLand;Vim;Visual Studio Code
# 73259                                 Visual Studio Code
# 73260                   Visual Studio;Visual Studio Code
# 73261               Eclipse;Notepad++;Visual Studio Code
# 73262                         Eclipse;Visual Studio Code
# 73263  IPython/Jupyter;Sublime Text;Vim;Visual Studio...
# 73264  IPython/Jupyter;Notepad++;Spyder;Vim;Visual St...
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                   Visual Studio;Visual Studio Code
#
#                             NEWCollabToolsWantToWorkWith  \
# 73245    Qt Creator;Vim;Visual Studio;Visual Studio Code
# 73246          Android Studio;IntelliJ;Notepad++;PyCharm
# 73247  Android Studio;GoLand;IntelliJ;Nano;PyCharm;Vi...
# 73248                                              Emacs
# 73249               IntelliJ;NetBeans;Visual Studio Code
# 73250                             Vim;Visual Studio Code
# 73251                  IntelliJ;Visual Studio Code;Xcode
# 73252                                 Visual Studio Code
# 73253                            GoLand;IntelliJ;PyCharm
# 73254                            IPython/Jupyter;RStudio
# 73255         Notepad++;Visual Studio;Visual Studio Code
# 73256      IntelliJ;Vim;Visual Studio;Visual Studio Code
# 73257                                 Visual Studio Code
# 73258                      GoLand;Vim;Visual Studio Code
# 73259                                 Visual Studio Code
# 73260                   Visual Studio;Visual Studio Code
# 73261                        IntelliJ;Visual Studio Code
# 73262                  Android Studio;Visual Studio Code
# 73263                Sublime Text;Vim;Visual Studio Code
# 73264            Notepad++;Spyder;Vim;Visual Studio Code
# 73265            Spyder;Visual Studio;Visual Studio Code
# 73266     RAD Studio (Delphi, C++ Builder);Visual Studio
# 73267                          Neovim;Visual Studio Code
#
#                                    OpSysProfessional use  \
# 73245                                            Windows
# 73246                                            Windows
# 73247                                                NaN
# 73248                                        Linux-based
# 73249                                                NaN
# 73250                                Linux-based;Windows
# 73251                                        Linux-based
# 73252                                Linux-based;Windows
# 73253                                              macOS
# 73254                                            Windows
# 73255                                            Windows
# 73256      Linux-based;Windows Subsystem for Linux (WSL)
# 73257                                                NaN
# 73258                                              macOS
# 73259                                              macOS
# 73260                                            Windows
# 73261  Linux-based;Windows;Windows Subsystem for Linu...
# 73262                                                NaN
# 73263                                              macOS
# 73264                                Linux-based;Windows
# 73265                                            Windows
# 73266                                            Windows
# 73267                                Linux-based;Windows
#
#                                        OpSysPersonal use VersionControlSystem  \
# 73245                                            Windows                  Git
# 73246                                            Windows                  Git
# 73247                                        Linux-based                  Git
# 73248                                        Linux-based                  Git
# 73249                                                NaN                  Git
# 73250                                        Linux-based                  Git
# 73251                                              macOS                  Git
# 73252                                            Windows                  Git
# 73253                                            Windows                  Git
# 73254                                            Windows                  Git
# 73255                                            Windows                  Git
# 73256  Linux-based;Windows;Windows Subsystem for Linu...                  Git
# 73257                                            Windows                  Git
# 73258                                Linux-based;Windows                  Git
# 73259          Windows;Windows Subsystem for Linux (WSL)                  Git
# 73260                                            Windows                  Git
# 73261          Windows;Windows Subsystem for Linux (WSL)                  Git
# 73262                                Linux-based;Windows                  Git
# 73263                                  Linux-based;macOS                  Git
# 73264                                Linux-based;Windows                  Git
# 73265                                            Windows                  Git
# 73266                                            Windows                  SVN
# 73267                                Linux-based;Windows                  Git
#
#                                            VCInteraction  \
# 73245  Code editor;Command-line;Version control hosti...
# 73246            Version control hosting service web GUI
# 73247  Code editor;Command-line;Version control hosti...
# 73248                           Code editor;Command-line
# 73249                                        Code editor
# 73250                           Code editor;Command-line
# 73251                           Code editor;Command-line
# 73252                                       Command-line
# 73253                                       Command-line
# 73254                                       Command-line
# 73255  Command-line;Version control hosting service w...
# 73256                           Code editor;Command-line
# 73257                                       Command-line
# 73258                                       Command-line
# 73259                           Code editor;Command-line
# 73260  Code editor;Command-line;Version control hosti...
# 73261  Code editor;Command-line;Version control hosti...
# 73262                                       Command-line
# 73263                           Code editor;Command-line
# 73264                           Code editor;Command-line
# 73265  Code editor;Command-line;Version control hosti...
# 73266          Dedicated version control GUI application
# 73267  Code editor;Command-line;Version control hosti...
#
#        VCHostingPersonal use  VCHostingProfessional use  \
# 73245                    NaN                        NaN
# 73246                    NaN                        NaN
# 73247                    NaN                        NaN
# 73248                    NaN                        NaN
# 73249                    NaN                        NaN
# 73250                    NaN                        NaN
# 73251                    NaN                        NaN
# 73252                    NaN                        NaN
# 73253                    NaN                        NaN
# 73254                    NaN                        NaN
# 73255                    NaN                        NaN
# 73256                    NaN                        NaN
# 73257                    NaN                        NaN
# 73258                    NaN                        NaN
# 73259                    NaN                        NaN
# 73260                    NaN                        NaN
# 73261                    NaN                        NaN
# 73262                    NaN                        NaN
# 73263                    NaN                        NaN
# 73264                    NaN                        NaN
# 73265                    NaN                        NaN
# 73266                    NaN                        NaN
# 73267                    NaN                        NaN
#
#                      OfficeStackAsyncHaveWorkedWith  \
# 73245                                           NaN
# 73246               Confluence;Jira Work Management
# 73247                                        Trello
# 73248        Confluence;Jira Work Management;Trello
# 73249                                           NaN
# 73250                                    Confluence
# 73251            Jira Work Management;Notion;Trello
# 73252                                           NaN
# 73253                          Jira Work Management
# 73254                                           NaN
# 73255                                           NaN
# 73256                          Jira Work Management
# 73257                                           NaN
# 73258                                        Notion
# 73259                  ClickUp;Jira Work Management
# 73260                                        Notion
# 73261                          Jira Work Management
# 73262                                        Notion
# 73263                          Jira Work Management
# 73264                                           NaN
# 73265                               Microsoft Lists
# 73266                                           NaN
# 73267  Confluence;Jira Work Management;Trello;Wrike
#
#         OfficeStackAsyncWantToWorkWith  \
# 73245                              NaN
# 73246  Confluence;Jira Work Management
# 73247                              NaN
# 73248                           Trello
# 73249                              NaN
# 73250                       Confluence
# 73251                              NaN
# 73252                              NaN
# 73253             Jira Work Management
# 73254                              NaN
# 73255                              NaN
# 73256             Jira Work Management
# 73257                              NaN
# 73258                              NaN
# 73259             Jira Work Management
# 73260                          ClickUp
# ...
# 73266                European  None of the above
# 73267  Or, in your own words:  None of the above
#
#                                             MentalHealth TBranch  \
# 73245                                  None of the above     NaN
# 73246                                  None of the above     Yes
# 73247                                  None of the above     NaN
# 73248                                  None of the above     NaN
# 73249                                  None of the above     NaN
# 73250                                  None of the above      No
# 73251                                  None of the above     Yes
# 73252                                                NaN     NaN
# 73253                                  None of the above     Yes
# 73254  I have a mood or emotional disorder (e.g., dep...     Yes
# 73255                                  None of the above     Yes
# 73256                                  None of the above     NaN
# 73257                                  None of the above     NaN
# 73258                                  None of the above     Yes
# 73259                                  None of the above     Yes
# 73260  I have a concentration and/or memory disorder ...     Yes
# 73261                                  None of the above     Yes
# 73262  I have a mood or emotional disorder (e.g., dep...     NaN
# 73263                                  None of the above     Yes
# 73264                                  None of the above     Yes
# 73265                                  None of the above     Yes
# 73266                                  None of the above      No
# 73267                                  None of the above     NaN
#
#                         ICorPM  WorkExp                 Knowledge_1  \
# 73245                      NaN      NaN                         NaN
# 73246           People manager      5.0              Strongly agree
# 73247                      NaN      NaN                         NaN
# 73248                      NaN      NaN                         NaN
# 73249                      NaN      NaN                         NaN
# 73250                      NaN      NaN                         NaN
# 73251           People manager      8.0              Strongly agree
# 73252                      NaN      NaN                         NaN
# 73253  Independent contributor      3.0              Strongly agree
# 73254  Independent contributor     16.0              Strongly agree
# 73255  Independent contributor      7.0  Neither agree nor disagree
# 73256                      NaN      NaN                         NaN
# 73257                      NaN      NaN                         NaN
# 73258  Independent contributor      1.0              Strongly agree
# 73259  Independent contributor      2.0                       Agree
# 73260  Independent contributor      3.0  Neither agree nor disagree
# 73261  Independent contributor      2.0                       Agree
# 73262                      NaN      NaN                         NaN
# 73263  Independent contributor      5.0                       Agree
# 73264  Independent contributor      6.0                       Agree
# 73265  Independent contributor     42.0                    Disagree
# 73266                      NaN      NaN                         NaN
# 73267                      NaN      NaN                         NaN
#
#                       Knowledge_2                 Knowledge_3  \
# 73245                         NaN                         NaN
# 73246  Neither agree nor disagree                    Disagree
# 73247                         NaN                         NaN
# 73248                         NaN                         NaN
# 73249                         NaN                         NaN
# 73250                         NaN                         NaN
# 73251  Neither agree nor disagree  Neither agree nor disagree
# 73252                         NaN                         NaN
# 73253                       Agree                    Disagree
# 73254              Strongly agree                    Disagree
# 73255                       Agree  Neither agree nor disagree
# 73256                         NaN                         NaN
# 73257                         NaN                         NaN
# 73258                    Disagree              Strongly agree
# 73259                    Disagree                       Agree
# 73260                       Agree                       Agree
# 73261                       Agree                       Agree
# 73262                         NaN                         NaN
# 73263                    Disagree              Strongly agree
# 73264                       Agree  Neither agree nor disagree
# 73265  Neither agree nor disagree                    Disagree
# 73266                         NaN                         NaN
# 73267                         NaN                         NaN
#
#                       Knowledge_4                 Knowledge_5  \
# 73245                         NaN                         NaN
# 73246              Strongly agree              Strongly agree
# 73247                         NaN                         NaN
# 73248                         NaN                         NaN
# 73249                         NaN                         NaN
# 73250                         NaN                         NaN
# 73251                       Agree                       Agree
# 73252                         NaN                         NaN
# 73253  Neither agree nor disagree                       Agree
# 73254  Neither agree nor disagree  Neither agree nor disagree
# 73255  Neither agree nor disagree  Neither agree nor disagree
# 73256                         NaN                         NaN
# 73257                         NaN                         NaN
# 73258                       Agree  Neither agree nor disagree
# 73259              Strongly agree              Strongly agree
# 73260                       Agree  Neither agree nor disagree
# 73261                       Agree                       Agree
# 73262                         NaN                         NaN
# 73263              Strongly agree              Strongly agree
# 73264                    Disagree                    Disagree
# 73265                       Agree                       Agree
# 73266                         NaN                         NaN
# 73267                         NaN                         NaN
#
#                       Knowledge_6                 Knowledge_7  \
# 73245                         NaN                         NaN
# 73246              Strongly agree                       Agree
# 73247                         NaN                         NaN
# 73248                         NaN                         NaN
# 73249                         NaN                         NaN
# 73250                         NaN                         NaN
# 73251  Neither agree nor disagree  Neither agree nor disagree
# 73252                         NaN                         NaN
# 73253                    Disagree              Strongly agree
# 73254  Neither agree nor disagree  Neither agree nor disagree
# 73255  Neither agree nor disagree  Neither agree nor disagree
# 73256                         NaN                         NaN
# 73257                         NaN                         NaN
# 73258                       Agree                       Agree
# 73259  Neither agree nor disagree              Strongly agree
# 73260                       Agree              Strongly agree
# 73261  Neither agree nor disagree                    Disagree
# 73262                         NaN                         NaN
# 73263              Strongly agree  Neither agree nor disagree
# 73264                       Agree                       Agree
# 73265                       Agree  Neither agree nor disagree
# 73266                         NaN                         NaN
# 73267                         NaN                         NaN
#
#              Frequency_1        Frequency_2        Frequency_3  \
# 73245                NaN                NaN                NaN
# 73246   1-2 times a week   10+ times a week   1-2 times a week
# 73247                NaN                NaN                NaN
# 73248                NaN                NaN                NaN
# 73249                NaN                NaN                NaN
# 73250                NaN                NaN                NaN
# 73251   1-2 times a week   1-2 times a week   1-2 times a week
# 73252                NaN                NaN                NaN
# 73253  6-10 times a week   3-5 times a week   1-2 times a week
# 73254   1-2 times a week  6-10 times a week  6-10 times a week
# 73255   1-2 times a week   1-2 times a week   1-2 times a week
# 73256                NaN                NaN                NaN
# 73257                NaN                NaN                NaN
# 73258   1-2 times a week   10+ times a week              Never
# 73259              Never   1-2 times a week                NaN
# 73260              Never   1-2 times a week   1-2 times a week
# 73261   1-2 times a week   3-5 times a week   1-2 times a week
# 73262                NaN                NaN                NaN
# 73263              Never              Never              Never
# 73264   1-2 times a week  6-10 times a week   10+ times a week
# 73265              Never              Never              Never
# 73266                NaN                NaN                NaN
# 73267                NaN                NaN                NaN
#
#               TimeSearching               TimeAnswering      Onboarding  \
# 73245                   NaN                         NaN             NaN
# 73246   15-30 minutes a day         30-60 minutes a day      Just right
# 73247                   NaN                         NaN             NaN
# 73248                   NaN                         NaN             NaN
# 73249                   NaN                         NaN             NaN
# 73250                   NaN                         NaN             NaN
# 73251   30-60 minutes a day         15-30 minutes a day      Just right
# 73252                   NaN                         NaN             NaN
# 73253  60-120 minutes a day        60-120 minutes a day      Just right
# 73254  60-120 minutes a day         30-60 minutes a day   Somewhat long
# 73255  60-120 minutes a day  Less than 15 minutes a day   Somewhat long
# 73256                   NaN                         NaN             NaN
# 73257                   NaN                         NaN             NaN
# 73258   15-30 minutes a day         15-30 minutes a day      Just right
# 73259   15-30 minutes a day  Less than 15 minutes a day  Somewhat short
# 73260   15-30 minutes a day         30-60 minutes a day       Very long
# 73261   15-30 minutes a day         15-30 minutes a day   Somewhat long
# 73262                   NaN                         NaN             NaN
# 73263   30-60 minutes a day  Less than 15 minutes a day      Just right
# 73264   15-30 minutes a day        60-120 minutes a day       Very long
# 73265   30-60 minutes a day        60-120 minutes a day      Just right
# 73266                   NaN                         NaN             NaN
# 73267                   NaN                         NaN             NaN
#
#                                         ProfessionalTech TrueFalse_1  \
# 73245                                                NaN         NaN
# 73246  DevOps function;Microservices;Developer portal...         Yes
# 73247                                                NaN         NaN
# 73248                                                NaN         NaN
# 73249                                                NaN         NaN
# 73250                                                NaN         NaN
# 73251  DevOps function;Developer portal or other cent...         Yes
# 73252                                                NaN         NaN
# 73253  Innersource initiative;DevOps function;Microse...         Yes
# 73254  Developer portal or other central places to fi...         Yes
# 73255  DevOps function;Microservices;Continuous integ...         Yes
# 73256                                                NaN         NaN
# 73257                                                NaN         NaN
# 73258  DevOps function;Microservices;Developer portal...         Yes
# 73259  DevOps function;Continuous integration (CI) an...         Yes
# 73260  DevOps function;Developer portal or other cent...          No
# 73261  Innersource initiative;DevOps function;Microse...         Yes
# 73262                                                NaN         NaN
# 73263  DevOps function;Microservices;Developer portal...         Yes
# 73264                                      None of these          No
# 73265                                      None of these          No
# 73266                                                NaN         NaN
# 73267                                                NaN         NaN
#
#       TrueFalse_2 TrueFalse_3           SurveyLength  \
# 73245         NaN         NaN  Appropriate in length
# 73246         Yes         Yes  Appropriate in length
# 73247         NaN         NaN  Appropriate in length
# 73248         NaN         NaN  Appropriate in length
# 73249         NaN         NaN  Appropriate in length
# 73250         NaN         NaN  Appropriate in length
# 73251          No         Yes  Appropriate in length
# 73252         NaN         NaN  Appropriate in length
# 73253         Yes         Yes  Appropriate in length
# 73254         Yes         Yes  Appropriate in length
# 73255         Yes         Yes               Too long
# 73256         NaN         NaN  Appropriate in length
# 73257         NaN         NaN              Too short
# 73258         Yes         Yes               Too long
# 73259         Yes         Yes  Appropriate in length
# 73260          No         Yes  Appropriate in length
# 73261         Yes         Yes  Appropriate in length
# 73262         NaN         NaN  Appropriate in length
# 73263         Yes         Yes               Too long
# 73264         Yes         Yes               Too long
# 73265          No          No  Appropriate in length
# 73266         NaN         NaN  Appropriate in length
# 73267         NaN         NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly
# 73245                        Easy                  NaN
# 73246  Neither easy nor difficult                  NaN
# 73247                        Easy                  NaN
# 73248                        Easy                  NaN
# 73249  Neither easy nor difficult                  NaN
# 73250                        Easy                  NaN
# 73251                        Easy                  NaN
# 73252                        Easy                  NaN
# 73253  Neither easy nor difficult                  NaN
# 73254  Neither easy nor difficult                  NaN
# 73255  Neither easy nor difficult                  NaN
# 73256                        Easy                  NaN
# 73257                        Easy                  NaN
# 73258  Neither easy nor difficult                  NaN
# 73259  Neither easy nor difficult                  NaN
# 73260                        Easy                  NaN
# 73261                        Easy                  NaN
# 73262  Neither easy nor difficult                  NaN
# 73263                        Easy                  NaN
# 73264                        Easy                  NaN
# 73265                        Easy                  NaN
# 73266                        Easy                  NaN
# 73267                        Easy                  NaN
